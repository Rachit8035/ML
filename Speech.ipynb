# %%
pip install SpeechRecognition pyttsx3 wikipedia
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---- ----------------------------------- 3.4/32.9 MB 17.9 MB/s eta 0:00:02
#    -------- ------------------------------- 7.3/32.9 MB 18.1 MB/s eta 0:00:02
#    -------------- ------------------------- 11.5/32.9 MB 18.6 MB/s eta 0:00:02
#    ------------------- -------------------- 15.7/32.9 MB 19.0 MB/s eta 0:00:01
#    ------------------------ --------------- 19.9/32.9 MB 19.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 24.1/32.9 MB 19.1 MB/s eta 0:00:01
#    -------------------------------- ------- 26.7/32.9 MB 18.3 MB/s eta 0:00:01
# ...

# %%
pip install pyaudio
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build pyaudio
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [22 lines of output]
#   WARNING:root:Warning: VCPKG_PATH envrionment variable not set.
#   C:\Users\Rachit\AppData\Local\Temp\pip-build-env-zfstxc0g\overlay\Lib\site-packages\setuptools\dist.py:765: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#   !!
#
#           ********************************************************************************
#           Please consider removing the following classifiers in favor of a SPDX license expression:
#
# ...
